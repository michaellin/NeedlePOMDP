# %% [markdown]
# # Needle Insertion Markov Decision Process

# %%
using POMDPs
using Distributions
using POMDPToolbox
using PyPlot
using JLD
importall Base

# %% [markdown]
# ## States

# %%
type NeedleState 
    x::Int64 # x position
    y::Int64 # y position
    psi::Int64 # orientation
    done::Bool # are we in a terminal state?
end

# %%
# initial state constructor
NeedleState(x::Int64, y::Int64, psi::Int64) = NeedleState(x,y,psi,false)
# checks if the position of two states are the same
posequal(s1::NeedleState, s2::NeedleState) = s1.x == s2.x && s1.y == s2.y && s1.psi == s2.psi
# copies state s2 to s1
function Base.copy!(s1::NeedleState, s2::NeedleState) 
    s1.x = s2.x
    s1.y = s2.y
    s1.psi = s2.psi
    s1.done = s2.done
    s1
end

Base.hash(s::NeedleState, h::UInt64 = zero(UInt64)) = hash(s.x, hash(s.y, hash(s.psi, hash(s.done, h))))
Base.isequal(s1::NeedleState,s2::NeedleState) = (s1.x == s2.x && s1.y == s2.y && s1.psi == s2.psi && s1.done == s2.done);
==(s1::NeedleState, s2::NeedleState) = (s1.x == s2.x && s1.y == s2.y && s1.psi == s2.psi && s1.done == s2.done);

# %% [markdown]
# ## POMDP

# %%
# the needle mdp type
type Needle <: POMDP{NeedleState, Symbol, NeedleState} # Note that our MDP is parametarized by the state and the action
    size_x::Int64 # x size of the grid
    size_y::Int64 # y size of the grid
    size_psi::Int64 # number of orientation bins
    reward_states::Vector{NeedleState} # target/obstacle states
    reward_values::Vector{Float64} # reward values for those states
    tprob::Array{Float64} # probability of transitioning to the desired state
    discount_factor::Float64 # disocunt factor
end

# %%
# we use key worded arguments so we can change any of the values we pass in 
function Needle(;sx::Int64 = 11, # size_x
                sy::Int64 = 11, # size_y
                spsi::Int64 = 8, # size_psi
                rs::Vector{NeedleState} = [[NeedleState(5,4,psi) for psi = 1:spsi]; # target states
                                            [NeedleState(4,6,psi) for psi = 1:spsi]; # obstacle states
                                            [NeedleState(6,6,psi) for psi = 1:spsi]; # obstacle states
                                            [NeedleState(7,4,psi) for psi = 1:spsi]; # obstacle states
                                            [NeedleState(0,y,psi) for y = 0:sy-1, psi = 3:7][:]; # boundary states
                                            [NeedleState(sx,y,psi) for y = 0:sy-1, psi = [1:3;7:spsi]][:];
                                            [NeedleState(x,0,psi) for x = 1:sx-2, psi = [5:spsi;1]][:];
                                            [NeedleState(x,sy,psi) for x = 1:sx-2, psi = 1:5][:]],
                rv::Vector{Float64} = [fill(100.0,spsi); fill(-20.0,spsi*3); fill(-100,(2*sx+2*sy-4)*5)],
                tp::Array{Float64} = [0.05, 0.9, 0.05, 0.0], # tprob
                discount_factor::Float64 = 0.85)
    return Needle(sx, sy, spsi, rs, rv, tp, discount_factor)
end

# we can now create a NeedleState mdp instance like this:
pomdp = Needle();
pomdp.reward_states # mdp contains all the defualt values from the constructor
# Out:
# 232-element Array{NeedleState,1}:
#  NeedleState(5,4,1,false)
#  NeedleState(5,4,2,false)
#  NeedleState(5,4,3,false)
#  NeedleState(5,4,4,false)
#  NeedleState(5,4,5,false)
#  NeedleState(5,4,6,false)
#  NeedleState(5,4,7,false)
#  NeedleState(5,4,8,false)
#  NeedleState(4,6,1,false)
#  NeedleState(4,6,2,false)
#  NeedleState(4,6,3,false)
#  NeedleState(4,6,4,false)
#  NeedleState(4,6,5,false)
#  ⋮
#  NeedleState(7,11,4,false)
#  NeedleState(8,11,4,false)
#  NeedleState(9,11,4,false)
#  NeedleState(1,11,5,false)
#  NeedleState(2,11,5,false)
#  NeedleState(3,11,5,false)
#  NeedleState(4,11,5,false)
#  NeedleState(5,11,5,false)
#  NeedleState(6,11,5,false)
#  NeedleState(7,11,5,false)
#  NeedleState(8,11,5,false)
#  NeedleState(9,11,5,false)

# %% [markdown]
# ## State Space ($ \mathcal{S}$)

# %%
type StateSpace <: AbstractSpace
    states::Vector{NeedleState}
end

# %%
function POMDPs.states(pomdp::Needle)
    s = NeedleState[] # initialize an array of NeedleStates
    # loop over all our states, remeber there is one binary variables: done (d)
    for d = 0:1, y = 1:pomdp.size_y, x = 1:pomdp.size_x, psi = 1:pomdp.size_psi
        push!(s, NeedleState(x,y,psi,d))
    end
    return StateSpace(s)
end;

# %%
function POMDPs.iterator(space::StateSpace)
    return space.states 
end;

# %%
function POMDPs.rand(rng::AbstractRNG, space::StateSpace, s::NeedleState)
    sp = space.states[rand(rng, 1:end)]
    copy!(s, sp)
    return s
end;
POMDPs.rand(rng::AbstractRNG, space::StateSpace) = space.states[rand(rng, 1:end)];

# %% [markdown]
# ## State Distribution

# %%
type NeedleDistribution <: AbstractDistribution
    neighbors::Array{NeedleState} # the states s' in the distribution
    probs::Array{Float64} # the probability corresponding to each state s'
    cat::Categorical # this comes from Distributions.jl and is used for sampling
end

# %%
function POMDPs.create_transition_distribution(pomdp::Needle)
    # can have at most five neighbors in grid world
    neighbors =  [NeedleState(i,i,1) for i = 1:5]
    probabilities = zeros(5) + 1.0/5.0
    cat = Categorical(5)
    return NeedleDistribution(neighbors, probabilities, cat)
end;

# %%
function POMDPs.iterator(d::NeedleDistribution)
    return d.neighbors
end;

# %%
function POMDPs.pdf(d::NeedleDistribution, s::NeedleState)
    for (i, sp) in enumerate(d.neighbors)
        if s == sp
            return d.probs[i]
        end
    end   
    return 0.0
end;

# %%
function POMDPs.rand(rng::AbstractRNG, d::NeedleDistribution, s::NeedleState)
    d.cat = Categorical(d.probs) # init the categorical distribution
    ns = d.neighbors[rand(d.cat)] # sample a neighbor state according to the distribution c
    copy!(s, ns)
    return s # return the pointer to s
end;

# %% [markdown]
# ### Initial State Distribution

# %%
type InitialStateDistribution <: AbstractDistribution
    states::Array{NeedleState}
    probs::Array{Float64}
end
POMDPs.iterator(d::InitialStateDistribution) = d.states

# %%
function POMDPs.initial_state_distribution(pomdp::Needle)
    s = iterator(states(pomdp));
    ns = n_states(pomdp);
    p = zeros(ns)+1.0/ns;
    return InitialStateDistribution(s,p);
end

function POMDPs.initial_state_distribution(pomdp::Needle, state::NeedleState)
    s = [state];
    p = [1.0];
    return InitialStateDistribution(s,p);
end

# %%
function POMDPs.rand(rng::AbstractRNG, d::InitialStateDistribution, s::NeedleState)
    cat = Categorical(d.probs) # init the categorical distribution
    ns = d.states[rand(cat)] # sample a neighbor state according to the distribution c
    copy!(s, ns)
    return s # return the pointer to s
end;

# %%
function POMDPs.pdf(d::InitialStateDistribution, s::NeedleState)
    for (i, sp) in enumerate(d.states)
        if s == sp
            return d.probs[i]
        end
    end   
    return 0.0
end;

# %% [markdown]
# ## Action Space ($\mathcal{A}$)

# %%
type ActionSpace <: AbstractSpace
    actions::Vector{Symbol}
end

# %%
function POMDPs.actions(pomdp::Needle)
    acts = [:cw, :ccw]
    return ActionSpace(acts)
end;
POMDPs.actions(pomdp::Needle, s::NeedleState, as::ActionSpace=actions(pomdp)) = as;

# %%
function POMDPs.iterator(space::ActionSpace)
    return space.actions 
end;

# %%
function POMDPs.rand(rng::AbstractRNG, space::ActionSpace, a::Symbol)
    return space.actions[rand(rng, 1:end)]
end;
function POMDPs.rand(rng::AbstractRNG, space::ActionSpace)
    a = NeedleAction(:cw)
    return rand(rng, space, a)
end;

# %% [markdown]
# ## Observation Space ($\mathcal{O}$)

# %%
type ObservationSpace <: AbstractSpace
    obs::Vector{NeedleState}
end

# %%
function POMDPs.observations(pomdp::Needle)
    s = NeedleState[] # initialize an array of GridWorldStates
    # loop over all our states, remeber there are two binary variables:
    # done (d)
    for d=0:1, psi = 1: pomdp.size_psi, y = 1:pomdp.size_y, x = 1:pomdp.size_x
        push!(s, NeedleState(x,y,psi,d))
    end
    return ObservationSpace(s)
end;

POMDPs.observations(pomdp::Needle, s::NeedleState, obs::ObservationSpace=observations(pomdp)) = obs;

# %%
function POMDPs.iterator(space::ObservationSpace)
    return space.obs 
end;

# %% [markdown]
# ## Observation Distribution

# %%
type ObsDistribution <: AbstractDistribution
    #curr_obs::NeedleState # the current observation
    neighbors::Array{NeedleState} # the states s' in the distribution
    probs::Array{Float64} # the probability corresponding to each state s'
    cat::Categorical # this comes from Distributions.jl and is used for sampling
end

# %%
function POMDPs.create_observation_distribution(pomdp::Needle)
    # 27 potential observations
    # initialize to whatever
    neighbors =  [NeedleState(i,j,k) for i = 1:3, j = 1:3, k = 1:3]
    probabilities = zeros(27) + 1.0/27.0
    cat = Categorical(27)
    return ObsDistribution(neighbors,probabilities,cat)
end;

# %%
function POMDPs.iterator(d::ObsDistribution)
    return d.neighbors # d.curr_obs
end;

# %%
function POMDPs.pdf(d::ObsDistribution, o::NeedleState)
    for (i, op) in enumerate(d.neighbors)
        if o == op
            return d.probs[i]
        end
    end   
    return 0.0
end

# %%
function POMDPs.rand(rng::AbstractRNG, d::ObsDistribution, o::NeedleState)
    d.cat = Categorical(d.probs) # init the categorical distribution
    no = d.neighbors[rand(d.cat)] # sample a neighbor state according to the distribution c
    copy!(o, no)
    return o # d.curr_obs
end
POMDPs.rand(rng::AbstractRNG, d::ObsDistribution) = rand(rng,d,NeedleState(1,1,1)) # d.curr_obs

# %% [markdown]
# ## Transition Model (T)

# %%
# transition helpers
function inbounds(pomdp::Needle,x::Int64,y::Int64,psi::Int64)
    if 1 <= x <= pomdp.size_x && 1 <= y <= pomdp.size_y && 1 <= psi <= pomdp.size_psi
        return true
    else
        return false
    end
end

function inbounds(pomdp::Needle,state::NeedleState)
    x = state.x
    y = state.y
    psi = state.psi
    return inbounds(pomdp, x, y, psi)
end

###########################################################

function atbounds(pomdp::Needle,x::Int64,y::Int64,psi::Int64)
    # at bounds if: at wall, facing outward or at corner
    if (x == 0 || x == pomdp.size_x) && (y == 0 || y == pomdp.size_y) # at corner
        return true
    elseif (x == 0 && 3 <= psi <= 7) || (x == pomdp.size_x && (7 <= psi || psi <= 3) ) ||
        (y == 0 && (5 <= psi || psi <= 1) ) || (y == pomdp.size_y && 1 <= psi <= 5) # at wall, facing outward
        return true
    else
        return false
    end
end

function atbounds(pomdp::Needle,state::NeedleState)
    x = state.x
    y = state.y
    psi = state.psi
    return atbounds(pomdp, x, y, psi)
end

###########################################################

function fill_probability!(p::Vector{Float64}, val::Float64, index::Int64)
    for i = 1:length(p)
        if i == index
            p[i] = val
        else
            p[i] = 0.0
        end
    end
end;

# %%
function POMDPs.transition(pomdp::Needle,
                            state::NeedleState,
                            action::Symbol,
                            d::NeedleDistribution=create_transition_distribution(pomdp))
    tp = pomdp.tprob
    
    a = action
    x = state.x
    y = state.y
    psi = state.psi
    
    neighbors = d.neighbors
    probability = d.probs
    
    # let's handle the done case first
    if state.done
        # can only transition to the same done state
        fill!(probability, 0.0)
        probability[1] = 1.0
        copy!(neighbors[1], state)
        # when we sample d, we will only get the state in neighbors[1] - our done state
        return d
    end
    
    fill!(probability, 0.0)

    if a == :ccw
        if psi == 1
            neighbors[1].x = x+1; neighbors[1].y = y;   neighbors[1].psi = psi; 
            neighbors[2].x = x+1; neighbors[2].y = y;   neighbors[2].psi = psi+1;
            neighbors[3].x = x+1; neighbors[3].y = y+1; neighbors[3].psi = psi+1;
            neighbors[4].x = x+1; neighbors[4].y = y+1; neighbors[4].psi = psi+2;
        elseif psi == 2
            neighbors[1].x = x+1; neighbors[1].y = y+1; neighbors[1].psi = psi; 
            neighbors[2].x = x+1; neighbors[2].y = y+1; neighbors[2].psi = psi+1;
            neighbors[3].x = x;   neighbors[3].y = y+1; neighbors[3].psi = psi+1;
            neighbors[4].x = x;   neighbors[4].y = y+1; neighbors[4].psi = psi+2;
        elseif psi == 3
            neighbors[1].x = x;   neighbors[1].y = y+1; neighbors[1].psi = psi; 
            neighbors[2].x = x;   neighbors[2].y = y+1; neighbors[2].psi = psi+1;
            neighbors[3].x = x-1; neighbors[3].y = y+1; neighbors[3].psi = psi+1;
            neighbors[4].x = x-1; neighbors[4].y = y+1; neighbors[4].psi = psi+2;
        elseif psi == 4
            neighbors[1].x = x-1; neighbors[1].y = y+1; neighbors[1].psi = psi; 
            neighbors[2].x = x-1; neighbors[2].y = y+1; neighbors[2].psi = psi+1;
            neighbors[3].x = x-1; neighbors[3].y = y;   neighbors[3].psi = psi+1;
            neighbors[4].x = x-1; neighbors[4].y = y;   neighbors[4].psi = psi+2;
        elseif psi == 5
            neighbors[1].x = x-1; neighbors[1].y = y;   neighbors[1].psi = psi; 
            neighbors[2].x = x-1; neighbors[2].y = y;   neighbors[2].psi = psi+1;
            neighbors[3].x = x-1; neighbors[3].y = y-1; neighbors[3].psi = psi+1;
            neighbors[4].x = x-1; neighbors[4].y = y-1; neighbors[4].psi = psi+2;
        elseif psi == 6
            neighbors[1].x = x-1; neighbors[1].y = y-1; neighbors[1].psi = psi; 
            neighbors[2].x = x-1; neighbors[2].y = y-1; neighbors[2].psi = psi+1;
            neighbors[3].x = x;   neighbors[3].y = y-1; neighbors[3].psi = psi+1;
            neighbors[4].x = x;   neighbors[4].y = y-1; neighbors[4].psi = psi+2;
        elseif psi == 7
            neighbors[1].x = x;   neighbors[1].y = y-1; neighbors[1].psi = psi; 
            neighbors[2].x = x;   neighbors[2].y = y-1; neighbors[2].psi = psi+1;
            neighbors[3].x = x+1; neighbors[3].y = y-1; neighbors[3].psi = psi+1;
            neighbors[4].x = x+1; neighbors[4].y = y-1; neighbors[4].psi = psi+2;
        elseif psi == 8
            neighbors[1].x = x+1; neighbors[1].y = y-1; neighbors[1].psi = psi; 
            neighbors[2].x = x+1; neighbors[2].y = y-1; neighbors[2].psi = psi+1;
            neighbors[3].x = x+1; neighbors[3].y = y;   neighbors[3].psi = psi+1;
            neighbors[4].x = x+1; neighbors[4].y = y;   neighbors[4].psi = psi+2;
        end
    elseif a == :cw
        if psi == 1
            neighbors[1].x = x+1; neighbors[1].y = y;   neighbors[1].psi = psi; 
            neighbors[2].x = x+1; neighbors[2].y = y;   neighbors[2].psi = psi+7;
            neighbors[3].x = x+1; neighbors[3].y = y-1; neighbors[3].psi = psi+7;
            neighbors[4].x = x+1; neighbors[4].y = y-1; neighbors[4].psi = psi+6;
        elseif psi == 2
            neighbors[1].x = x+1; neighbors[1].y = y+1; neighbors[1].psi = psi; 
            neighbors[2].x = x+1; neighbors[2].y = y+1; neighbors[2].psi = psi+7;
            neighbors[3].x = x+1; neighbors[3].y = y;   neighbors[3].psi = psi+7;
            neighbors[4].x = x+1; neighbors[4].y = y;   neighbors[4].psi = psi+6;
        elseif psi == 3
            neighbors[1].x = x;   neighbors[1].y = y+1; neighbors[1].psi = psi; 
            neighbors[2].x = x;   neighbors[2].y = y+1; neighbors[2].psi = psi+7;
            neighbors[3].x = x+1; neighbors[3].y = y+1; neighbors[3].psi = psi+7;
            neighbors[4].x = x+1; neighbors[4].y = y+1; neighbors[4].psi = psi+6;
        elseif psi == 4
            neighbors[1].x = x-1; neighbors[1].y = y+1; neighbors[1].psi = psi; 
            neighbors[2].x = x-1; neighbors[2].y = y+1; neighbors[2].psi = psi+7;
            neighbors[3].x = x;   neighbors[3].y = y+1; neighbors[3].psi = psi+7;
            neighbors[4].x = x;   neighbors[4].y = y+1; neighbors[4].psi = psi+6;
        elseif psi == 5
            neighbors[1].x = x-1; neighbors[1].y = y;   neighbors[1].psi = psi; 
            neighbors[2].x = x-1; neighbors[2].y = y;   neighbors[2].psi = psi+7;
            neighbors[3].x = x-1; neighbors[3].y = y+1; neighbors[3].psi = psi+7;
            neighbors[4].x = x-1; neighbors[4].y = y+1; neighbors[4].psi = psi+6;
        elseif psi == 6
            neighbors[1].x = x-1; neighbors[1].y = y-1; neighbors[1].psi = psi; 
            neighbors[2].x = x-1; neighbors[2].y = y-1; neighbors[2].psi = psi+7;
            neighbors[3].x = x-1; neighbors[3].y = y;   neighbors[3].psi = psi+7;
            neighbors[4].x = x-1; neighbors[4].y = y;   neighbors[4].psi = psi+6;
        elseif psi == 7
            neighbors[1].x = x;   neighbors[1].y = y-1; neighbors[1].psi = psi; 
            neighbors[2].x = x;   neighbors[2].y = y-1; neighbors[2].psi = psi+7;
            neighbors[3].x = x-1; neighbors[3].y = y-1; neighbors[3].psi = psi+7;
            neighbors[4].x = x-1; neighbors[4].y = y-1; neighbors[4].psi = psi+6;
        elseif psi == 8
            neighbors[1].x = x+1; neighbors[1].y = y-1; neighbors[1].psi = psi; 
            neighbors[2].x = x+1; neighbors[2].y = y-1; neighbors[2].psi = psi+7;
            neighbors[3].x = x;   neighbors[3].y = y-1; neighbors[3].psi = psi+7;
            neighbors[4].x = x;   neighbors[4].y = y-1; neighbors[4].psi = psi+6;
        end
    end
    # make sure psi is between 1 and 8
    for i = 1:4
        neighbors[i].psi = mod(neighbors[i].psi,8)
        if neighbors[i].psi == 0
            neighbors[i].psi = 8;
        end
    end
    neighbors[5].x = x; neighbors[5].y = y; neighbors[5].psi = psi;
    
    # initialize done states 
    for i = 1:5 neighbors[i].done = false end
    reward_states = pomdp.reward_states
    
    # detection of done states
    n = length(reward_states)
    for i = 1:n
        # terminate at target/obstacle
        if posequal(state, reward_states[i])
            fill_probability!(probability, 1.0, 5)
            neighbors[5].done = true
            return d
        end
        # terminate at boundary
        if atbounds(pomdp, state)
            fill_probability!(probability, 1.0, 5)
            neighbors[5].done = true
            return d
        end
    end
    
    if !inbounds(pomdp, neighbors[1]) || !inbounds(pomdp, neighbors[2]) ||
        !inbounds(pomdp, neighbors[3]) || !inbounds(pomdp, neighbors[4]) # at least one of the neighbors is outside bounds
        fill_probability!(probability, 1.0, 5) # stuck in current state when terminated
    else # none of the neighbors is outside bounds
        probability[1:4] = tp
    end
    
    return d
end;

# %% [markdown]
# ## Observation Model

# %%
function POMDPs.observation(pomdp::Needle,
                           action::Symbol,
                           state::NeedleState,
                           d::ObsDistribution=create_observation_distribution(pomdp))
    a = action
    x = state.x
    y = state.y
    psi = state.psi
    
    neighbor = d.neighbors
    probability = d.probs
    
    neighbor[1].x = x; neighbor[1].y = y; neighbor[1].psi = psi
    neighbor[2].x = x; neighbor[2].y = y; neighbor[2].psi = psi+1
    neighbor[3].x = x; neighbor[3].y = y; neighbor[3].psi = psi-1
    
    neighbor[4].x = x+1; neighbor[4].y = y; neighbor[4].psi = psi
    neighbor[5].x = x+1; neighbor[5].y = y; neighbor[5].psi = psi+1
    neighbor[6].x = x+1; neighbor[6].y = y; neighbor[6].psi = psi-1
    
    neighbor[7].x = x; neighbor[7].y = y+1; neighbor[7].psi = psi
    neighbor[8].x = x; neighbor[8].y = y+1; neighbor[8].psi = psi+1
    neighbor[9].x = x; neighbor[9].y = y+1; neighbor[9].psi = psi-1
    
    neighbor[10].x = x+1; neighbor[10].y = y+1; neighbor[10].psi = psi
    neighbor[11].x = x+1; neighbor[11].y = y+1; neighbor[11].psi = psi+1
    neighbor[12].x = x+1; neighbor[12].y = y+1; neighbor[12].psi = psi-1

    neighbor[13].x = x-1; neighbor[13].y = y; neighbor[13].psi = psi
    neighbor[14].x = x-1; neighbor[14].y = y; neighbor[14].psi = psi+1
    neighbor[15].x = x-1; neighbor[15].y = y; neighbor[15].psi = psi-1
    
    neighbor[16].x = x; neighbor[16].y = y-1; neighbor[16].psi = psi
    neighbor[17].x = x; neighbor[17].y = y-1; neighbor[17].psi = psi+1
    neighbor[18].x = x; neighbor[18].y = y-1; neighbor[18].psi = psi-1
    
    neighbor[19].x = x-1; neighbor[19].y = y-1; neighbor[19].psi = psi
    neighbor[20].x = x-1; neighbor[20].y = y-1; neighbor[20].psi = psi+1
    neighbor[21].x = x-1; neighbor[21].y = y-1; neighbor[21].psi = psi-1
    
    neighbor[22].x = x-1; neighbor[22].y = y+1; neighbor[22].psi = psi
    neighbor[23].x = x-1; neighbor[23].y = y+1; neighbor[23].psi = psi+1
    neighbor[24].x = x-1; neighbor[24].y = y+1; neighbor[24].psi = psi-1
    
    neighbor[25].x = x+1; neighbor[25].y = y-1; neighbor[25].psi = psi
    neighbor[26].x = x+1; neighbor[26].y = y-1; neighbor[26].psi = psi+1
    neighbor[27].x = x+1; neighbor[27].y = y-1; neighbor[27].psi = psi-1
    
    probability=[0.36,0.12,0.12,0.03,0.01,0.01,0.03,0.01,0.01,0.03,0.01,0.01,0.03,0.01,0.01,0.03,0.01,0.01,0.03,0.01,0.01,0.03,0.01,0.01,0.03,0.01,0.01];
    
#     d.curr_obs = NeedleState(x, y, psi);
    return d
end

POMDPs.observation(pomdp::Needle,
                   state::NeedleState,
                   action::Symbol,
                   sp::NeedleState,
                    d::ObsDistribution = create_observation_distribution(pomdp)) = observation(pomdp, action, sp, d);

# %% [markdown]
# ## Reward Model (R)

# %%
function POMDPs.reward(pomdp::Needle, state::NeedleState, action::Symbol) #deleted action
    if state.done
        return 0.0
    end
    r = 0.0
    reward_states = pomdp.reward_states
    reward_values = pomdp.reward_values
    n = length(reward_states)
    for i = 1:n
        if posequal(state, reward_states[i]) # reward, obstacle and wall states
            r += reward_values[i]
        end
    end
    r += -1; # penalty for every step taken
    return r
end;

# %% [markdown]
# ## Miscellaneous functions

# %%
POMDPs.n_states(pomdp::Needle) = 2*pomdp.size_x*pomdp.size_y*pomdp.size_psi
POMDPs.n_actions(pomdp::Needle) = 2;
POMDPs.n_observations(pomdp::Needle) = 2*pomdp.size_x*pomdp.size_y*pomdp.size_psi;
POMDPs.discount(pomdp::Needle) = pomdp.discount_factor;

# %%
function POMDPs.state_index(pomdp::Needle, state::NeedleState)
    sd = Int(state.done + 1)
    return sub2ind((pomdp.size_x, pomdp.size_y, pomdp.size_psi, 2, 2), state.x, state.y, state.psi, sd)
end;

# %%
function POMDPs.isterminal(pomdp::Needle, s::NeedleState)
    s.done ? (return true) : (return false)
end;

# %%
POMDPs.create_state(pomdp::Needle) = NeedleState(1,1,1)
POMDPs.create_action(pomdp::Needle) = :cw;
POMDPs.create_observation(pomd::Needle) = NeedleState(1,1,1)

# %% [markdown]
# ## SARSOP Solver

# %%
using SARSOP # load the module
# initialize our tiger POMDP
pomdp = Needle()

# initialize the solver
solver = SARSOPSolver(timeout=600.0) # 5 min
# run the solve function
policy = solve(solver, pomdp)
# Out:
# Generating a pomdpx file: model.pomdpx
#
# Loading the model ...
#   input file   : model.pomdpx
# WARNING
#   model.pomdpx:Line 35236:
#   In Observation Function Tables observation
#   In instance a0 s0
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s1
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s2
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s3
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s4
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s5
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s6
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s7
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s8
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s9
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s10
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s11
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s12
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s13
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s14
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s15
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s16
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s17
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s18
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s19
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s20
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s21
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s22
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s23
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s24
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s25
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s26
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s27
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s28
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s29
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s30
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s31
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s32
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s33
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s34
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s35
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s36
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s37
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s38
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s39
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s40
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s41
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s42
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s43
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s44
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s45
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s46
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s47
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s48
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s49
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s50
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s51
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s52
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s53
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s54
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s55
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s56
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s57
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s58
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s59
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s60
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s61
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s62
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s63
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s64
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s65
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s66
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s67
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s68
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s69
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s70
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s71
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s72
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s73
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s74
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s75
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s76
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s77
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s78
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s79
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s80
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s81
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s82
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s83
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s84
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s85
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s86
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s87
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s88
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s89
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s90
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s91
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s92
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s93
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s94
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s95
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s96
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s103
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s104
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s111
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s112
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s119
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s120
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s127
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s128
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s135
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s136
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s143
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s144
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s151
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s152
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s159
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s160
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s167
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s168
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s169
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s170
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s171
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s172
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s173
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s174
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s175
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s176
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s177
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s178
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s179
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s180
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s181
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s182
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s183
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s184
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s191
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s192
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s199
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s200
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s207
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s208
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s215
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s216
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s223
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s224
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s231
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s232
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s239
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s240
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s247
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s248
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s255
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s256
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s257
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s258
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s259
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s260
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s261
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s262
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s263
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s264
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s265
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s266
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s267
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s268
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s269
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s270
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s271
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s272
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s279
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s280
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s287
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s288
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s295
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s296
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s303
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s304
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s311
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s312
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s319
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s320
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s327
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s328
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s335
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s336
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s343
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s344
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s345
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s346
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s347
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s348
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s349
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s350
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s351
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s352
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s353
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s354
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s355
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s356
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s357
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s358
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s359
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s360
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s367
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s368
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s375
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s376
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s383
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s384
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s391
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s392
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s399
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s400
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s407
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s408
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s415
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s416
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s423
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s424
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s431
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s432
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s433
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s434
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s435
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s436
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s437
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s438
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s439
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s440
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s441
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s442
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s443
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s444
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s445
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s446
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s447
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s448
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s455
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s456
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s463
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s464
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s471
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s472
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s479
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s480
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s487
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s488
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s495
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s496
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s503
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s504
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s511
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s512
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s519
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s520
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s521
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s522
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s523
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s524
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s525
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s526
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s527
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s528
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s529
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s530
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s531
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s532
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s533
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s534
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s535
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s536
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s543
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s544
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s551
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s552
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s559
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s560
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s567
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s568
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s575
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s576
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s583
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s584
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s591
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s592
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s599
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s600
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s607
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s608
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s609
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s610
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s611
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s612
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s613
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s614
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s615
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s616
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s617
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s618
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s619
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s620
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s621
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s622
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s623
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s624
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s631
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s632
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s639
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s640
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s647
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s648
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s655
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s656
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s663
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s664
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s671
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s672
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s679
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s680
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s687
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s688
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s695
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s696
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s697
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s698
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s699
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s700
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s701
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s702
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s703
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s704
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s705
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s706
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s707
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s708
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s709
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s710
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s711
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s712
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s719
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s720
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s727
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s728
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s735
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s736
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s743
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s744
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s751
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s752
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s759
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s760
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s767
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s768
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s775
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s776
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s783
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s784
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s785
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s786
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s787
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s788
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s789
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s790
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s791
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s792
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s793
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s794
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s795
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s796
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s797
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s798
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s799
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s800
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s807
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s808
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s815
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s816
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s823
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s824
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s831
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s832
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s839
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s840
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s847
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s848
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s855
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s856
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s863
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s864
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s871
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s872
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s873
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s874
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s875
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s876
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s877
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s878
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s879
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s880
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s881
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s882
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s883
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s884
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s885
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s886
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s887
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s888
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s889
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s890
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s891
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s892
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s893
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s894
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s895
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s896
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s897
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s898
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s899
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s900
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s901
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s902
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s903
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s904
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s905
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s906
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s907
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s908
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s909
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s910
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s911
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s912
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s913
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s914
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s915
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s916
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s917
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s918
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s919
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s920
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s921
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s922
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s923
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s924
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s925
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s926
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s927
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s928
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s929
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s930
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s931
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s932
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s933
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s934
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s935
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s936
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s937
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s938
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s939
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s940
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s941
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s942
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s943
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s944
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s945
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s946
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s947
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s948
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s949
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s950
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s951
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s952
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s953
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s954
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s955
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s956
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s957
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s958
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s959
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s960
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s961
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s962
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s963
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s964
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s965
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s966
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s967
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s968
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s969
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s970
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s971
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s972
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s973
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s974
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s975
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s976
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s977
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s978
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s979
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s980
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s981
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s982
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s983
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s984
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s985
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s986
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s987
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s988
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s989
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s990
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s991
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s992
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s993
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s994
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s995
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s996
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s997
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s998
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s999
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1000
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1001
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1002
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1003
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1004
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1005
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1006
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1007
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1008
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1009
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1010
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1011
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1012
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1013
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1014
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1015
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1016
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1017
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1018
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1019
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1020
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1021
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1022
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1023
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1024
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1025
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1026
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1027
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1028
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1029
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1030
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1031
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1032
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1033
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1034
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1035
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1036
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1037
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1038
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1039
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1040
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1041
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1042
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1043
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1044
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1045
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1046
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1047
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1048
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s1049
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1050
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1051
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1052
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1053
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1054
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1055
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a0 s1056
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1057
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1058
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1059
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1060
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1061
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1062
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1063
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a0 s1064
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1071
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1072
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1079
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1080
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1087
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1088
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1095
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1096
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1103
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1104
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1111
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a0 s1112
# ...
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1800
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1807
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1808
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1815
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1816
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1823
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1824
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1831
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1832
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1839
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1840
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1841
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1842
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1843
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1844
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1845
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1846
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1847
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1848
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a1 s1849
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1850
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1851
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1852
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1853
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1854
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1855
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a1 s1856
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1857
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1858
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1859
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1860
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1861
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1862
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1863
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1864
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1865
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1866
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1867
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1868
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1869
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1870
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1871
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1872
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1873
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1874
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1875
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1876
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1877
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1878
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1879
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1880
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1881
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1882
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1883
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1884
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1885
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1886
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1887
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1888
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1889
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1890
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1891
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1892
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1893
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1894
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1895
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1896
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1897
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1898
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1899
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1900
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1901
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1902
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1903
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1904
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1905
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1906
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1907
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1908
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1909
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1910
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1911
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1912
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1913
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1914
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1915
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1916
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1917
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1918
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1919
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1920
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1921
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1922
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1923
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1924
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1925
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1926
#   Probabilities sum up to 0.666667. It should sum up to 1
#   In instance a1 s1927
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1928
#   Probabilities sum up to 0.296296. It should sum up to 1
#   In instance a1 s1929
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1930
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1931
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1932
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1933
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1934
#   Probabilities sum up to 0.444444. It should sum up to 1
#   In instance a1 s1935
#   Probabilities sum up to 0.296296. It should sum up to 1
#   loading time : 1.94s
#
# SARSOP initializing ...
#   initialization time : 2.88s
#
# -------------------------------------------------------------------------------
#  Time   |#Trial |#Backup |LBound    |UBound    |Precision  |#Alphas |#Beliefs
# -------------------------------------------------------------------------------
#  2.88    0       0        -14.4694   -3.61532   10.8541     2        1
#  3.93    5       53       -8.42913   -6.22986   2.19927     55       28
#  4.94    10      100      -8.30624   -6.26887   2.03738     102      52
#  6.2     15      153      -8.26011   -6.29987   1.96024     155      78
#  7.66    22      203      -8.19516   -6.3344    1.86076     205      103
#  9.35    27      251      -8.1627    -6.3532    1.8095      253      127
#  11.43   34      301      -8.12071   -6.37958   1.74113     303      152
#  13.89   42      350      -8.10787   -6.40983   1.69805     352      180
#  16.61   48      400      -8.09088   -6.44194   1.64895     402      205
#  19.86   55      453      -8.07475   -6.47302   1.60173     455      228
#  23.45   62      503      -8.06683   -6.49215   1.57468     505      252
#  26.36   67      550      -8.05974   -6.51329   1.54645     552      276
#  31.11   74      603      -8.04253   -6.52343   1.5191      605      300
#  34.39   78      650      -8.03582   -6.52648   1.50934     652      325
#  38.21   84      700      -8.02851   -6.53494   1.49357     702      348
#  44.38   89      753      -8.01943   -6.5462    1.47324     751      371
#  48.76   96      803      -8.01358   -6.55777   1.45581     801      394
#  53.21   102     850      -8.00452   -6.57107   1.43345     848      417
#  60.55   107     900      -7.99818   -6.58168   1.4165      893      443
#  66.17   115     953      -7.99429   -6.60667   1.38762     946      464
#  71.37   121     1000     -7.98932   -6.61094   1.37838     993      486
#  77.59   128     1051     -7.98626   -6.62747   1.35879     1044     509
#  86.99   135     1100     -7.98239   -6.63294   1.34945     1090     531
#  93.36   140     1150     -7.97103   -6.64398   1.32704     1140     554
#  100.19  146     1205     -7.96659   -6.65255   1.31403     1195     578
#  105.85  152     1250     -7.96332   -6.6536    1.30972     1240     599
#  112.35  157     1303     -7.9561    -6.66245   1.29365     1293     620
#  124.06  162     1351     -7.94974   -6.66813   1.2816      1334     641
#  130.46  167     1400     -7.94734   -6.6774    1.26994     1383     665
#  139.03  176     1451     -7.94021   -6.69882   1.24139     1434     686
#  145.7   181     1501     -7.93852   -6.70237   1.23615     1484     707
#  153.54  187     1550     -7.9366    -6.71108   1.22552     1533     732
#  161.24  193     1600     -7.93289   -6.71725   1.21564     1583     751
#  168.91  200     1650     -7.92918   -6.72113   1.20805     1633     771
#  185.76  207     1703     -7.92596   -6.73214   1.19382     1680     792
#  192.7   212     1750     -7.92574   -6.73267   1.19307     1727     811
#  200.92  217     1803     -7.92149   -6.73383   1.18766     1780     834
#  208.33  222     1850     -7.91966   -6.73546   1.18419     1827     854
#  217.47  227     1900     -7.91933   -6.74203   1.1773      1877     877
#  226.27  232     1951     -7.91386   -6.7477    1.16616     1928     899
#  235.24  238     2000     -7.90213   -6.75141   1.15073     1977     921
#  245.11  245     2050     -7.89823   -6.75702   1.14121     2027     940
#  266.17  252     2101     -7.89699   -6.766     1.13098     2072     960
#  275.46  257     2151     -7.89633   -6.7688    1.12753     2122     981
#  284.75  263     2200     -7.89581   -6.77222   1.12359     2171     1002
#  294.92  267     2250     -7.8932    -6.77431   1.11889     2221     1026
#  305.89  274     2300     -7.89158   -6.77712   1.11446     2271     1044
#  316.84  280     2353     -7.89012   -6.77962   1.1105      2324     1066
#  325.58  285     2400     -7.88932   -6.78092   1.10841     2371     1085
#  337.66  292     2450     -7.88602   -6.78413   1.10189     2421     1108
#  349.24  298     2503     -7.88231   -6.79539   1.08693     2474     1131
#  374.84  304     2550     -7.88092   -6.79616   1.08477     2510     1150
#  388.03  310     2601     -7.87252   -6.80571   1.06682     2561     1174
#  398.75  317     2650     -7.87104   -6.80891   1.06213     2610     1194
#  410.58  323     2703     -7.87007   -6.81601   1.05406     2663     1216
#  423.03  329     2751     -7.86907   -6.81795   1.05112     2711     1236
#  435.06  335     2803     -7.86811   -6.81956   1.04856     2762     1255
#  445.87  340     2853     -7.86682   -6.82378   1.04304     2812     1276
#  455.93  345     2900     -7.86583   -6.82604   1.03978     2859     1297
#  469.34  349     2950     -7.86406   -6.82749   1.03657     2909     1320
#  481.13  354     3000     -7.85861   -6.83057   1.02804     2959     1344
#  494.76  360     3050     -7.85487   -6.8378    1.01707     3009     1366
#  507.42  366     3100     -7.85392   -6.83942   1.0145      3059     1384
#  542.31  370     3150     -7.8533    -6.84224   1.01106     3097     1406
#  555.56  376     3201     -7.85212   -6.84435   1.00777     3148     1424
#  568.55  382     3253     -7.85083   -6.84817   1.00266     3200     1444
#  579.55  386     3301     -7.84949   -6.8538    0.995699    3248     1466
#  593.43  391     3355     -7.84733   -6.8583    0.98903     3302     1489
#  606.74  396     3400     -7.84548   -6.86083   0.984654    3347     1512
# -------------------------------------------------------------------------------
#
# SARSOP finishing ...
#   Preset timeout reached
#   Timeout     : 600.000000s
#   Actual Time : 606.740000s
#
# -------------------------------------------------------------------------------
#  Time   |#Trial |#Backup |LBound    |UBound    |Precision  |#Alphas |#Beliefs
# -------------------------------------------------------------------------------
#  607.12  396     3400     -7.84548   -6.86083   0.984654    3347     1512
# -------------------------------------------------------------------------------
#
# Writing out policy ...
#   output file : out.policy
# out.policy:2490: parser error : Premature end of data in tag Vector line 2490
# out.policy:2490: parser error : Premature end of data in tag AlphaVector line 3
# out.policy:2490: parser error : Premature end of data in tag Policy line 2
# LoadError: LightXML.XMLParseError{String}("Failure in parsing an XML file.")
# while loading In[39], in expression starting on line 8
#
#  in parse_file(::String) at /home/juser/.julia/v0.5/LightXML/src/document.jl:89
#  in read_pomdp(::String) at /home/juser/.julia/v0.5/POMDPXFiles/src/read.jl:73
#  in POMDPXFiles.POMDPAlphas(::String) at /home/juser/.julia/v0.5/POMDPXFiles/src/policy.jl:53
#  in solve(::SARSOP.SARSOPSolver, ::Needle, ::SARSOP.POMDPPolicy) at /home/juser/.julia/v0.5/SARSOP/src/solver.jl:105
#  in solve(::SARSOP.SARSOPSolver, ::Needle) at /home/juser/.julia/v0.5/SARSOP/src/solver.jl:98

# %%
# using SARSOP
# filename = "SARSOP policy"
# policy = JLD.load(string(filename,".jld"), "policy")

# %% [markdown]
# ## Simulation

# %%
using POMDPToolbox

init_state = initial_state_distribution(pomdp, NeedleState(3,10,7))
hist_SARSOP = HistoryRecorder(max_steps=100)
r = simulate(hist_SARSOP, pomdp, policy, updater(policy), init_state)

println("Total discounted reward: $r")

if hist_SARSOP.state_hist[end].x == pomdp.reward_states[1].x && hist_SARSOP.state_hist[end].y == pomdp.reward_states[1].y
    println("Target reached")
else
    println("Target missed")
end
# Out:
# LoadError: UndefVarError: policy not defined
# while loading In[41], in expression starting on line 5

# %%
# define tissue environment
plot([0 10 10 0 0]',[0 0 10 10 0]',linewidth=10,color="r") # tissue bounds
plot(pomdp.reward_states[1].x,pomdp.reward_states[1].y,marker="o",markersize=30,color="g",markeredgecolor="none")
plot(pomdp.reward_states[9].x,pomdp.reward_states[9].y,marker="o",markersize=30,color="r",markeredgecolor="none")
plot(pomdp.reward_states[18].x,pomdp.reward_states[18].y,marker="o",markersize=30,color="r",markeredgecolor="none")
plot(pomdp.reward_states[27].x,pomdp.reward_states[27].y,marker="o",markersize=30,color="r",markeredgecolor="none")


# needle trajectory
steps = length(hist_SARSOP.state_hist)
for i = 1:steps-1 
    state = hist_SARSOP.state_hist[i]
    action = hist_SARSOP.action_hist[i]
    if action == :cw
        c = "y"
    else
        c = "b"
    end
    plot(state.x,state.y,color=c,marker="o",markersize=15)
    quiver(state.x,state.y,0.5*cos((state.psi-1)*pi/4),0.5*sin((state.psi-1)*pi/4))
end

title(@sprintf("Needle tip trajectory (SARSOP): reward = %0.2f",r))
axis("equal")
axis([-1, 11, -1, 11])
xlabel("x")
ylabel("y")
grid(true)

savefig("SARSOP plot")
# Out:
# LoadError: UndefVarError: r not defined
# while loading In[42], in expression starting on line 23

# %%
# # save the policy
# filename = "SARSOP policy disct=0.85"
# JLD.save(string(filename,".jld"),"policy",policy)
